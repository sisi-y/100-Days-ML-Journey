# %% [markdown]
# <a href="https://colab.research.google.com/github/sisi-y/100-Days-ML-Journey/blob/main/SalaryQualifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
applicant_name = "Wangari"
knows_python = True
english_level = "fluent"
hours_per_day = 5
has_degree = True
monthly_salary_needed = 50000

print(f"\n Evaluating application for: {applicant_name}")
print("-" * 40)

if knows_python:
  print("Python: PASS")
else:
  print("Python: FAIL-Python knowledge required")

if english_level == "fluent":
  print("English: PASS - Fluent level")
elif english_level == "intermediate":
  print("English - conditional - intermediate accepted")
else:
  print("English: Fail - Higher level required")

if hours_per_day >=5:
  print(f"Availability: Pass- {hours_per_day} hours/day")
else:
  print(f"Availability: Fail - minimum 5 hours per day. You have {hours_per_day} hours")

print("-" * 40)
if knows_python and english_level == "fluent" and hours_per_day >= 5:
  print(f"RESULT: {applicant_name} qualifies for the AI Trainer role")
  print(f"Estimated monthly earning: KES {hours_per_day * 22 * 600}")
else:
  print(f"{applicant_name} does not qualify yet. Keep building")
# Out:
#  Evaluating application for: Wangari
# ----------------------------------------
# Python: PASS
# English: PASS - Fluent level
# Availability: Pass- 5 hours/day
# ----------------------------------------
# RESULT: Wangari qualifies for the AI Trainer role
# Estimated monthly earning: KES 66000
